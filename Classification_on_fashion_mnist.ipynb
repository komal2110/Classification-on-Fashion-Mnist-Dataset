# %%
#Upgrade pip and tensorflow
# !pip install --upgrade pip --user
# !pip install tensorflow==2.0.0 --user
# Out:
# Requirement already up-to-date: pip in ./.local/lib/python3.6/site-packages (20.0.2)

# %%
#Import necessary libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.0.0

# %%
#Load fashion mnist dataset
mnist = tf.keras.datasets.fashion_mnist

# %%
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()

# %%
print(len(training_images))
plt.imshow(training_images[50000])
# Out:
# 60000

# %%
training_images = training_images / 255.0
test_images = test_images / 255.0

# %%
#Define a model
model = tf.keras.models.Sequential([tf.keras.layers.Flatten(),
                                  tf.keras.layers.Dense(128, activation=tf.nn.relu),
                                  tf.keras.layers.Dense(10, activation=tf.nn.softmax)])

model.compile(optimizer = tf.optimizers.Adam(), loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
#Train a model
model.fit(training_images, training_labels, epochs = 10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.5004 - accuracy: 0.8233
# Epoch 2/10
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.3795 - accuracy: 0.8633
# Epoch 3/10
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.3380 - accuracy: 0.8760
# Epoch 4/10
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.3153 - accuracy: 0.8869
# Epoch 5/10
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.2958 - accuracy: 0.8906
# Epoch 6/10
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.2805 - accuracy: 0.8960
# Epoch 7/10
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.2702 - accuracy: 0.8995
# Epoch 8/10
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.2580 - accuracy: 0.9041
# Epoch 9/10
# 60000/60000 [==============================] - 2s 33us/sample - loss: 0.2486 - accuracy: 0.9072
# Epoch 10/10
# 60000/60000 [==============================] - 2s 38us/sample - loss: 0.2393 - accuracy: 0.9111

# %%
#Evaluate model on test images
model.evaluate(test_images, test_labels)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.3331599213063717, 0.8838]

# %%
classifications = model.predict(test_images)

# %%
print(classifications[3000])
print(test_labels[3000])
# Out:
# [1.3352620e-07 9.9999893e-01 4.2862037e-11 9.3021958e-07 4.4773576e-09
#  2.2042525e-16 1.2758600e-08 3.7562319e-23 2.9195017e-13 2.1448949e-12]
# 1
